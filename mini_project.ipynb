# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_excel(r'C:\Users\vivek\Downloads\owid-covid-data.xlsx', index_col=0)

# %%
data.head()
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-01-03          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-04          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-05          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-06          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-07          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 327243 entries, AFG to ZWE
# Data columns (total 66 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   continent                                   311694 non-null  object
#  1   location                                    327243 non-null  object
#  2   date                                        327243 non-null  object
#  3   total_cases                                 289884 non-null  float64
#  4   new_cases                                   318216 non-null  float64
#  5   new_cases_smoothed                          316953 non-null  float64
#  6   total_deaths                                268842 non-null  float64
#  7   new_deaths                                  318271 non-null  float64
#  8   new_deaths_smoothed                         317041 non-null  float64
# ...

# %%
data.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.898840e+05  3.182160e+05        3.169530e+05  2.688420e+05
# mean   6.170323e+06  1.025784e+04        1.029132e+04  8.309868e+04
# std    3.811065e+07  1.141598e+05        9.775639e+04  4.272334e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    7.344000e+03  0.000000e+00        7.140000e-01  1.250000e+02
# 50%    6.415300e+04  4.000000e+00        3.128600e+01  1.232000e+03
# 75%    6.757358e+05  3.260000e+02        5.762860e+02  1.111100e+04
# max    7.682370e+08  8.401763e+06        6.402720e+06  6.951664e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  318271.000000        317041.000000            289884.000000
# mean       92.860072            93.213361             94045.724004
# std       765.933703           600.737767            144282.192372
# min         0.000000             0.000000                 0.000000
# ...

# %%
data.isnull().sum()
# Out:
# continent                                   15549
# location                                        0
# date                                            0
# total_cases                                 37359
# new_cases                                    9027
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       315834
# excess_mortality_cumulative                315834
# excess_mortality                           315834
# excess_mortality_cumulative_per_million    315834
# Length: 66, dtype: int64

# %%
data.shape
# Out:
# (327243, 66)

# %%
data.head()
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-01-03          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-04          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-05          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-06          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-07          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
#
# ...

# %%
data=data.fillna(0)

# %%
death_above_1L=data.loc[data['total_deaths']>1000000]

# %%
death_above_1L.head()
# Out:
#          continent location        date  total_cases  new_cases  \
# iso_code
# OWID_ASI         0     Asia  2021-08-23   67751366.0   223045.0
# OWID_ASI         0     Asia  2021-08-24   67996943.0   245577.0
# OWID_ASI         0     Asia  2021-08-25   68271535.0   274592.0
# OWID_ASI         0     Asia  2021-08-26   68553921.0   282386.0
# OWID_ASI         0     Asia  2021-08-27   68827135.0   273214.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# OWID_ASI          253857.143     1002030.0      4883.0             4551.286
# OWID_ASI          253620.000     1006184.0      4154.0             4528.429
# OWID_ASI          253847.429     1010841.0      4657.0             4581.000
# OWID_ASI          254788.143     1015376.0      4535.0             4534.286
# OWID_ASI          255107.857     1019410.0      4034.0             4440.571
#
#           total_cases_per_million  ...  male_smokers  handwashing_facilities  \
# ...

# %%
du=data['location'].unique()
du.shape
# Out:
# (255,)

# %%
#print(data.groupby(['location']).get_group(death_above_1L))

# %%
groupby=data[data['total_deaths']>1000000].groupby(['location'])['total_deaths'].sum()

# %%
groupby
# Out:
# location
# Asia                   9.970110e+08
# Europe                 1.414353e+09
# European Union         6.048727e+08
# High income            2.052381e+09
# Lower middle income    8.719801e+08
# North America          9.814844e+08
# South America          9.575202e+08
# United States          4.416802e+08
# Upper middle income    1.933041e+09
# World                  5.262464e+09
# Name: total_deaths, dtype: float64

# %%
data[data['total_deaths']>1000000].groupby(['location'])[['total_deaths','total_cases']].sum().plot(marker='o')
plt.title("world")
plt.xticks(rotation=30,ha='right')
# Out:
# (array([-2.,  0.,  2.,  4.,  6.,  8., 10.]),
#  [Text(-2.0, 0, 'Upper middle income'),
#   Text(0.0, 0, 'Asia'),
#   Text(2.0, 0, 'European Union'),
#   Text(4.0, 0, 'Lower middle income'),
#   Text(6.0, 0, 'South America'),
#   Text(8.0, 0, 'Upper middle income'),
#   Text(10.0, 0, '')])

# %%
data[data['total_deaths']>1000000].query('location== "Europe"').groupby(['location'])[['total_deaths','total_cases','total_vaccinations']].sum()
# Out:
#           total_deaths   total_cases  total_vaccinations
# location
# Europe    1.414353e+09  1.360007e+11        9.224968e+11

# %%
data[data['total_deaths']>1000000].query('location== "Europe"').groupby(['location'])[['total_deaths','total_cases','total_vaccinations']].plot()
plt.title("Europe")
plt.xticks(rotation=30,ha='right')
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000.]),
#  [Text(-200.0, 0, 'OWID_EUR'),
#   Text(0.0, 0, 'OWID_EUR'),
#   Text(200.0, 0, 'OWID_EUR'),
#   Text(400.0, 0, 'OWID_EUR'),
#   Text(600.0, 0, 'OWID_EUR'),
#   Text(800.0, 0, 'OWID_EUR'),
#   Text(1000.0, 0, '')])

# %%
data[data['total_deaths']>1000000].query('location== "World"').groupby(['location'])[['total_deaths','total_cases','total_vaccinations']].sum()
# Out:
#           total_deaths   total_cases  total_vaccinations
# location
# World     5.262464e+09  4.203072e+11        8.325074e+12

# %%
data[data['total_deaths']>1000000].query('location== "World"').groupby(['location'])[['total_deaths','total_cases','total_vaccinations']].plot()
plt.title("World")
plt.xticks(rotation=30,ha='right')
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000., 1200.]),
#  [Text(-200.0, 0, 'OWID_WRL'),
#   Text(0.0, 0, 'OWID_WRL'),
#   Text(200.0, 0, 'OWID_WRL'),
#   Text(400.0, 0, 'OWID_WRL'),
#   Text(600.0, 0, 'OWID_WRL'),
#   Text(800.0, 0, 'OWID_WRL'),
#   Text(1000.0, 0, 'OWID_WRL'),
#   Text(1200.0, 0, '')])

# %%
data[data['total_deaths']>1000000].query('location== "Upper middle income"').groupby(['location'])[['total_deaths','total_cases','total_vaccinations']].plot()
plt.title("Upper middle income")
plt.xticks(rotation=30,ha='right')
plt.show()

# %%
data[data['total_deaths']>1000000].query('location== "High income"').groupby(['location'])[['total_deaths','total_cases','total_vaccinations']].plot()
plt.title("High income")
plt.xticks(rotation=30,ha='right')
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000.]),
#  [Text(-200.0, 0, 'OWID_HIC'),
#   Text(0.0, 0, 'OWID_HIC'),
#   Text(200.0, 0, 'OWID_HIC'),
#   Text(400.0, 0, 'OWID_HIC'),
#   Text(600.0, 0, 'OWID_HIC'),
#   Text(800.0, 0, 'OWID_HIC'),
#   Text(1000.0, 0, '')])

# %%
data[data['total_deaths']>1000000].groupby(['date'])[['total_deaths','total_cases']].sum().plot()
# Out:
# <Axes: xlabel='location'>

# %%
data[data['total_deaths']>1000000].groupby(['date'])[['total_deaths','total_cases']].sum().plot()
# Out:
# <Axes: xlabel='date'>

# %%
data[data['total_deaths']>1000000].groupby(['date'])[['total_deaths','total_cases']].sum().plot()
ran=len(data[data['total_deaths']>1000000].groupby(['date'])[['total_deaths','total_cases']].sum())
plt.set_xticklabels([])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 3
#       1 data[data['total_deaths']>1000000].groupby(['date'])[['total_deaths','total_cases']].sum().plot()
#       2 ran=len(data[data['total_deaths']>1000000].groupby(['date'])[['total_deaths','total_cases']].sum())
# ----> 3 plt.set_xticklabels([])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_xticklabels'

# %%
data[data['total_deaths']>1000000].groupby(['location'])[['total_deaths','total_cases']].plot()
# Out:
# location
# Asia                   Axes(0.125,0.11;0.775x0.77)
# Europe                 Axes(0.125,0.11;0.775x0.77)
# European Union         Axes(0.125,0.11;0.775x0.77)
# High income            Axes(0.125,0.11;0.775x0.77)
# Lower middle income    Axes(0.125,0.11;0.775x0.77)
# North America          Axes(0.125,0.11;0.775x0.77)
# South America          Axes(0.125,0.11;0.775x0.77)
# United States          Axes(0.125,0.11;0.775x0.77)
# Upper middle income    Axes(0.125,0.11;0.775x0.77)
# World                  Axes(0.125,0.11;0.775x0.77)
# dtype: object
